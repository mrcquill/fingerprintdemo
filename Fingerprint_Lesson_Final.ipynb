# %%
#from google.colab import drive
#drive.mount('/content/drive')
import sys
sys.path.append("/content/drive/MyDrive/RET Program UB/Fingerprints/")
import enhance_fingerprint
import fingerprint_feature_extractor
import cv2
from google.colab.patches import cv2_imshow
orig=cv2.imread("/content/drive/MyDrive/RET Program UB/Fingerprints/5.jpg")
cv2_imshow(orig)
img = cv2.imread("/content/drive/MyDrive/RET Program UB/Fingerprints/5.jpg", 0)				# read the input image --> You can enhance the fingerprint image using the "fingerprint_enhancer" library
out=enhance_fingerprint.enhance_Fingerprint(img)
cv2_imshow(out)
FeaturesTerminations, FeaturesBifurcations = fingerprint_feature_extractor.extract_minutiae_features(out, showResult=True)
# Out:
# <PIL.Image.Image image mode=RGB size=430x600 at 0x7FA083B91510>
# <PIL.Image.Image image mode=L size=430x600 at 0x7FA067EA8850>
# <PIL.Image.Image image mode=RGB size=430x600 at 0x7FA0614FE050>
